# %%
import pandas as pd

df=pd.read_csv("/content/drive/MyDrive/annotations_final.txt")
df
# Out:
#           id                                              title  \
# 0     8es6qn  I cut myself for the first time in a year toda...
# 1     ar89pm                        Anybody hate spring/summer?
# 2     5g4v1n        So I'm staring at this tablet of Lexapro...
# 3     9x8h3g  Found a poem sort of thing, very emo (ha ha ha...
# 4     es440i                                   You don't get it
# ...      ...                                                ...
# 2867  lm7uix  My life just feels like this one big party Im ...
# 2868  ac1aj9                  Just move away from your parents!
# 2869  hng1f5                               That feeling when...
# 2870  4pfk9x           Life just keeps getting more complicated
# 2871  ae5lum                           This is how I look like:
#
#                                                selftext  labels  \
# 0     ... and hated that I still loved it. The burni...  [1, 0]
# 1     .....And even so, when depression is not too s...  [1, 1]
# ...

# %%
df2=df["text"]

# %%
df2
# Out:
# 0       I cut myself for the first time in a year toda...
# 1       Anybody hate springsummer. And even so, when d...
# 2       So Im staring at this tablet of Lexapro. and I...
# 3       Found a poem sort of thing, very emo ha ha ha ...
# 4       You dont get it. It gets better Stop thinking ...
#                               ...
# 2867    My life just feels like this one big party Im ...
# 2868    Just move away from your parents. You probably...
# 2869    That feeling when. You wake up, and that itsel...
# 2870    Life just keeps getting more complicated. You ...
# 2871    This is how I look like. my eyes are ususally ...
# Name: text, Length: 2872, dtype: object

# %%
df2[2870]
# Out:
# 'Life just keeps getting more complicated. You would think after years of bad breaks, something good would come into your life and stay but in reality the world owes you nothing and will chew you up and spit you out if you let it and i do. I dont feel like Im strong enough to be a part of the life i was dealt with.i am so frustrated and full of anxiety that i am always clenching my teeth and hold my breath. I think it got so bad that it caused my sleep apnea to get worse. I just dont know what to do anymore. I have these really depressive episodes from time to time and i cant seem to control my emotions anymore. When it gets really bad i have a total mental breakdown. I want all this pain to finally end. Cant go another year go by wasted being miserable and hopeless. I just cant.'

# %%
# !pip install --upgrade openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import openai

api_key='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'
openai.api_key = api_key

# %%
df2[0]
# Out:
# 'I cut myself for the first time in a year today. and hated that I still loved it. The burning sensation from the blade on my arm and leg. I didnt even cut deep, I barely bled, but the feeling was still almost the same, but without the kick of seeing my own blood trail down my limbs staining the covers in my bed. I told myself that I was only going to cut a few times, but here I am with surely thirty new scars on my body. I fucking hate myself.'

# %%
df
# Out:
#           id                                              title  \
# 0     8es6qn  I cut myself for the first time in a year toda...
# 1     ar89pm                        Anybody hate spring/summer?
# 2     5g4v1n        So I'm staring at this tablet of Lexapro...
# 3     9x8h3g  Found a poem sort of thing, very emo (ha ha ha...
# 4     es440i                                   You don't get it
# ...      ...                                                ...
# 2867  lm7uix  My life just feels like this one big party Im ...
# 2868  ac1aj9                  Just move away from your parents!
# 2869  hng1f5                               That feeling when...
# 2870  4pfk9x           Life just keeps getting more complicated
# 2871  ae5lum                           This is how I look like:
#
#                                                selftext  labels  \
# 0     ... and hated that I still loved it. The burni...  [1, 0]
# 1     .....And even so, when depression is not too s...  [1, 1]
# ...

# %%
display(df.iloc[2690])
# Out:
# id                                                     eu2jzp
# title                                                 Venting
# selftext    This is probably going to look like the most s...
# labels                                                 [0, 1]
# disorder                                 {'anxiety_disorder'}
# text        Venting. This is probably going to look like t...
# Name: 2690, dtype: object

# %%
examples = df.groupby('labels').apply(lambda x: x.sample(1))
print(examples)
# Out:
#                  id                                         title  \
# labels
# [0, 0] 2665  ctqk2x                       Widsom teeth extraction
# [0, 1] 745   5vbzrp        Is anyone else scared to make friends?
# [1, 0] 1653  5nds9s                  I just want to be left alone
# [1, 1] 1915  ei3pw1  How often does depression skip a generation?
#
#                                                       selftext  labels  \
# labels
# [0, 0] 2665  This friday im getting rid of my four widsom m...  [0, 0]
# [0, 1] 745   I can count on one hand the people who have al...  [0, 1]
# [1, 0] 1653  I'm a junior in college in my second day of cl...  [1, 0]
# [1, 1] 1915  Im not sure about my grandparents but I suspec...  [1, 1]
#
#                                                 disorder  \
# labels
# [0, 0] 2665                            {'control_group'}
# [0, 1] 745                          {'anxiety_disorder'}
# [1, 0] 1653                      {'depressive_disorder'}
# ...

# %%
import openai

api_key='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'
openai.api_key = api_key

examples = [
    (df2[0], "depressive_disorder"),
    (df2[1], "depressive_disorder_and_anxiety_disorder"),
    (df2[2690], "anxiety_disorder"),
    (df2[2870], "Neither_depressive_disorder_nor_anxiety_disorder")
]

# Add the examples to the prompt
prompt = "Label the following sentences into one of these categories: depressive_disorder, depressive_disorder_and_anxiety_disorder, anxiety_disorder, Neither_depressive_disorder_nor_anxiety_disorder.\n\n"
for input, output in examples:
    prompt += f"Text: {input}\nLabel: {output}\n\n"

# Add some new data to label
prompt += df2[31]+"\nLabel:"
print(prompt)

# Ask GPT-3 to complete the prompt
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=prompt,
    stop="\n",
    temperature=0,
    max_tokens=100
)
print(response)
print(response["choices"][0]["text"])
# Out:
# Label the following sentences into one of these categories: depressive_disorder, depressive_disorder_and_anxiety_disorder, anxiety_disorder, Neither_depressive_disorder_nor_anxiety_disorder.
#
# Text: I cut myself for the first time in a year today. and hated that I still loved it. The burning sensation from the blade on my arm and leg. I didnt even cut deep, I barely bled, but the feeling was still almost the same, but without the kick of seeing my own blood trail down my limbs staining the covers in my bed. I told myself that I was only going to cut a few times, but here I am with surely thirty new scars on my body. I fucking hate myself.
# Label: depressive_disorder
#
# ...
