# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dreddit_df = pd.read_csv('../data/dataset_analysis/v_info/dreddit_std_null_vinfo.csv')
dreddit_df
# Out:
#                                               sentence1  label      H_yb  \
# 0     He said he had not felt that way before, sugge...      1  0.929386
# 1     Hey there r/assistance, Not sure if this is th...      0  1.074249
# 2     My mom then hit me with the newspaper and it s...      1  0.929386
# 3     until i met my new boyfriend, he is amazing, h...      1  0.929386
# 4     October is Domestic Violence Awareness Month a...      1  0.929386
# ...                                                 ...    ...       ...
# 2833  * Her, a week ago: Precious, how are you? (I i...      0  1.074249
# 2834  I don't have the ability to cope with it anymo...      1  0.929386
# 2835  In case this is the first time you're reading ...      0  1.074249
# 2836  Do you find this normal? They have a good rela...      0  1.074249
# 2837  I was talking to my mom this morning and she s...      1  0.929386
#
#           H_yx  correct_yx  predicted_label       PVI
# 0     0.415394        True                1  0.513992
# 1     0.092361        True                0  0.981888
# 2     0.484073        True                1  0.445313
# 3     0.209886        True                1  0.719500
# 4     0.591781        True                1  0.337605
# ...        ...         ...              ...       ...
# 2833  0.146746        True                0  0.927503
# 2834  0.070778        True                1  0.858608
# 2835  0.082895        True                0  0.991354
# 2836  0.372701        True                0  0.701548
# 2837  0.266099        True                1  0.663287
#
# [2838 rows x 7 columns]

# %%
DATD_df = pd.read_csv('../data/dataset_analysis/v_info/DATD_std_null_vinfo.csv')
DATD_df
# Out:
#                                              sentence1  label      H_yb  \
# 0               @user Me talking to my antidepressants      1  0.965121
# 1    going to attempt at least to change this sour ...      1  0.965121
# 2            flighty sag placements make me anxioussss      0  1.035743
# 3    I'm going to buy cream cheese after work and s...      1  0.965121
# 4    My anxiety and stress levels for today are act...      1  0.965121
# ..                                                 ...    ...       ...
# 895  Libra culture is using the same nail polish co...      0  1.035743
# 896  anyways, my last year of college starts today ...      0  1.035743
# 897    'Dad.. I'm depressed.' 'Hi depressed, I'm Dad.'      0  1.035743
# 898                   respiratory depression be my god      0  1.035743
# 899  deactivated my main because not only do i feel...      0  1.035743
#
#          H_yx  correct_yx  predicted_label       PVI
# 0    0.959775        True                1  0.005346
# 1    0.582790        True                1  0.382331
# 2    0.832954        True                0  0.202790
# 3    0.838917        True                1  0.126204
# 4    0.569318        True                1  0.395803
# ..        ...         ...              ...       ...
# 895  0.645651        True                0  0.390093
# 896  1.031957       False                1  0.003787
# 897  1.019089       False                1  0.016655
# 898  1.392413       False                1 -0.356669
# 899  1.221749       False                1 -0.186006
#
# [900 rows x 7 columns]

# %%
MHCD_anxiety_df = pd.read_csv('../data/dataset_analysis/v_info/MHCD_std_null_vinfo-anxiety_label.csv')
MHCD_anxiety_df
# Out:
#           id                                              title  \
# 0     8es6qn  I cut myself for the first time in a year toda...
# 1     ar89pm                        Anybody hate spring/summer?
# 2     5g4v1n        So I'm staring at this tablet of Lexapro...
# 3     9x8h3g  Found a poem sort of thing, very emo (ha ha ha...
# 4     es440i                                   You don't get it
# ...      ...                                                ...
# 2867  lm7uix  My life just feels like this one big party Im ...
# 2868  ac1aj9                  Just move away from your parents!
# 2869  hng1f5                               That feeling when...
# 2870  4pfk9x           Life just keeps getting more complicated
# 2871  ae5lum                           This is how I look like:
#
#                                                selftext multilabel_clf_label  \
# 0     ... and hated that I still loved it. The burni...               [1, 0]
# 1     .....And even so, when depression is not too s...               [1, 1]
# 2     ...and I'm not sure what to do. I guess I don'...               [1, 1]
# 3     "I am delicate and bitter. I am sweet on the o...               [1, 0]
# 4     "It gets better" "Stop thinking about it" "get...               [1, 1]
# ...                                                 ...                  ...
# 2867  You know the feeling. Where youre just so over...               [1, 0]
# 2868  You probably want to hear my sob story as much...               [0, 0]
# 2869  You wake up, and that itself just brings you s...               [0, 0]
# 2870  You would think after years of bad breaks, som...               [0, 0]
# 2871  my eyes are ususally very red because of the t...               [0, 0]
#
#                                          disorder  \
# 0                         {'depressive_disorder'}
# 1     {'depressive_disorder', 'anxiety_disorder'}
# 2     {'depressive_disorder', 'anxiety_disorder'}
# 3                         {'depressive_disorder'}
# 4     {'depressive_disorder', 'anxiety_disorder'}
# ...                                           ...
# 2867                      {'depressive_disorder'}
# 2868                            {'control_group'}
# 2869                            {'control_group'}
# 2870                            {'control_group'}
# 2871                            {'control_group'}
#
#                                               sentence1  \
# 0     I cut myself for the first time in a year toda...
# 1     Anybody hate springsummer. And even so, when d...
# 2     So Im staring at this tablet of Lexapro. and I...
# 3     Found a poem sort of thing, very emo ha ha ha ...
# 4     You dont get it. It gets better Stop thinking ...
# ...                                                 ...
# 2867  My life just feels like this one big party Im ...
# 2868  Just move away from your parents. You probably...
# 2869  That feeling when. You wake up, and that itsel...
# 2870  Life just keeps getting more complicated. You ...
# 2871  This is how I look like. my eyes are ususally ...
#
#                  multiclass_clf_label  depression_label  anxiety_label  \
# 0                          Depression                 1              0
# 1     Comorbid (Depression + Anxiety)                 1              1
# 2     Comorbid (Depression + Anxiety)                 1              1
# 3                          Depression                 1              0
# 4     Comorbid (Depression + Anxiety)                 1              1
# ...                               ...               ...            ...
# 2867                       Depression                 1              0
# 2868                           Normal                 0              0
# 2869                           Normal                 0              0
# 2870                           Normal                 0              0
# 2871                           Normal                 0              0
#
#          H_yb      H_yx  correct_yx  predicted_label       PVI
# 0     0.36575  0.264283        True                0  0.101467
# 1     2.15885  2.430993       False                0 -0.272143
# 2     2.15885  1.789537       False                0  0.369313
# 3     0.36575  0.176797        True                0  0.188953
# 4     2.15885  3.148635       False                0 -0.989785
# ...       ...       ...         ...              ...       ...
# 2867  0.36575  0.171012        True                0  0.194738
# 2868  0.36575  0.256886        True                0  0.108864
# 2869  0.36575  0.229581        True                0  0.136169
# 2870  0.36575  0.253897        True                0  0.111853
# 2871  0.36575  0.246041        True                0  0.119709
#
# [2872 rows x 14 columns]

# %%
MHCD_depression_df = pd.read_csv('../data/dataset_analysis/v_info/MHCD_std_null_vinfo-depression_label.csv')
MHCD_depression_df
# Out:
#           id                                              title  \
# 0     8es6qn  I cut myself for the first time in a year toda...
# 1     ar89pm                        Anybody hate spring/summer?
# 2     5g4v1n        So I'm staring at this tablet of Lexapro...
# 3     9x8h3g  Found a poem sort of thing, very emo (ha ha ha...
# 4     es440i                                   You don't get it
# ...      ...                                                ...
# 2867  lm7uix  My life just feels like this one big party Im ...
# 2868  ac1aj9                  Just move away from your parents!
# 2869  hng1f5                               That feeling when...
# 2870  4pfk9x           Life just keeps getting more complicated
# 2871  ae5lum                           This is how I look like:
#
#                                                selftext multilabel_clf_label  \
# 0     ... and hated that I still loved it. The burni...               [1, 0]
# 1     .....And even so, when depression is not too s...               [1, 1]
# 2     ...and I'm not sure what to do. I guess I don'...               [1, 1]
# 3     "I am delicate and bitter. I am sweet on the o...               [1, 0]
# 4     "It gets better" "Stop thinking about it" "get...               [1, 1]
# ...                                                 ...                  ...
# 2867  You know the feeling. Where youre just so over...               [1, 0]
# 2868  You probably want to hear my sob story as much...               [0, 0]
# 2869  You wake up, and that itself just brings you s...               [0, 0]
# 2870  You would think after years of bad breaks, som...               [0, 0]
# 2871  my eyes are ususally very red because of the t...               [0, 0]
#
#                                          disorder  \
# 0                         {'depressive_disorder'}
# 1     {'depressive_disorder', 'anxiety_disorder'}
# 2     {'depressive_disorder', 'anxiety_disorder'}
# 3                         {'depressive_disorder'}
# 4     {'depressive_disorder', 'anxiety_disorder'}
# ...                                           ...
# 2867                      {'depressive_disorder'}
# 2868                            {'control_group'}
# 2869                            {'control_group'}
# 2870                            {'control_group'}
# 2871                            {'control_group'}
#
#                                               sentence1  \
# 0     I cut myself for the first time in a year toda...
# 1     Anybody hate springsummer. And even so, when d...
# 2     So Im staring at this tablet of Lexapro. and I...
# 3     Found a poem sort of thing, very emo ha ha ha ...
# 4     You dont get it. It gets better Stop thinking ...
# ...                                                 ...
# 2867  My life just feels like this one big party Im ...
# 2868  Just move away from your parents. You probably...
# 2869  That feeling when. You wake up, and that itsel...
# 2870  Life just keeps getting more complicated. You ...
# 2871  This is how I look like. my eyes are ususally ...
#
#                  multiclass_clf_label  depression_label  anxiety_label  \
# 0                          Depression                 1              0
# 1     Comorbid (Depression + Anxiety)                 1              1
# 2     Comorbid (Depression + Anxiety)                 1              1
# 3                          Depression                 1              0
# 4     Comorbid (Depression + Anxiety)                 1              1
# ...                               ...               ...            ...
# 2867                       Depression                 1              0
# 2868                           Normal                 0              0
# 2869                           Normal                 0              0
# 2870                           Normal                 0              0
# 2871                           Normal                 0              0
#
#           H_yb      H_yx  correct_yx  predicted_label       PVI
# 0     0.893915  1.464073       False                0 -0.570159
# 1     0.893915  1.486325       False                0 -0.592410
# 2     0.893915  0.311600        True                1  0.582314
# 3     0.893915  1.855977       False                0 -0.962063
# 4     0.893915  1.301212       False                0 -0.407298
# ...        ...       ...         ...              ...       ...
# 2867  0.893915  1.717239       False                0 -0.823325
# 2868  1.114509  0.563353        True                0  0.551156
# 2869  1.114509  1.087553       False                1  0.026956
# 2870  1.114509  1.402387       False                1 -0.287877
# 2871  1.114509  0.278537        True                0  0.835972
#
# [2872 rows x 14 columns]

# %%
dreddit_df.plot.hist(y='PVI', bins=5, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
DATD_df.plot.hist(y='PVI', bins=5, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
MHCD_anxiety_df.plot.hist(y='PVI', bins=5, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
MHCD_depression_df.plot.hist(y='PVI', bins=5, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#define points values by group
A = MHCD_depression_df['PVI'].tolist()
B = MHCD_anxiety_df['PVI'].tolist()
C = dreddit_df['PVI'].tolist()
D = DATD_df['PVI'].tolist()

#add three histograms to one plot
plt.hist(A, alpha=0.5, label='MHCD_depression')
plt.hist(B, alpha=0.5, label='MHCD_anxiety')
plt.hist(C, alpha=0.5, label='Dreddit')
plt.hist(D, alpha=0.5, label='DATD')

#add plot title and axis labels
plt.title('PVI distribution by dataset')
plt.xlabel('Points')
plt.ylabel('Frequency')

#add legend
plt.legend(title='Team')

#display plot
plt.show()

# %%
print("MHCD_depression_df", round(MHCD_depression_df['PVI'].mean(), 4), round( MHCD_depression_df['PVI'].std(), 4))
print("MHCD_anxiety_df", round(MHCD_anxiety_df['PVI'].mean(), 4), round( MHCD_anxiety_df['PVI'].std(), 4))
print("dreddit_df", round(dreddit_df['PVI'].mean(), 4), round( dreddit_df['PVI'].std(), 4))
print("DATD_df", round(DATD_df['PVI'].mean(), 4), round( DATD_df['PVI'].std(), 4))
# Out:
# MHCD_depression_df 0.2287 0.4864
# MHCD_anxiety_df 0.0645 0.2698
# dreddit_df 0.4362 0.6393
# DATD_df 0.1258 0.2375

# %%
no_gp = {
    "MHCD_depression" : MHCD_depression_df['PVI'].tolist(),
    "MHCD_anxiety" : MHCD_anxiety_df['PVI'].tolist(),
    "Dreddit" : dreddit_df['PVI'].tolist(),
    "DATD" : DATD_df['PVI'].tolist(),
}
# With val group annotations
bplot = plt.boxplot(
    list(no_gp.values()),
    vert=True,  # vertical box alignment
     patch_artist=True,  # fill with color
     showmeans=True,
     meanline=True,
     meanprops={'linewidth': 2, 'color': 'black'},
     medianprops={'linewidth': 2, 'color': 'orange'},
     widths=0.6,
     labels=list(no_gp.keys())
)  # will be used to label x-ticks

plt.title('Performance on Waterbirds without validation group annotations', loc='center', wrap=True, pad=20)

# fill with colors
# colors = ['tab:pink', 'lightblue', 'lightgreen']
colors = ['tab:cyan', 'tab:blue', 'tab:red', 'tab:pink']
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

# adding horizontal grid lines
#     ax.set_xlabel('Methods', loc='center', wrap=True, fontsize=20, labelpad=20)
#     ax.set_ylabel('Worst Group Accuracy', loc='center', wrap=True, fontsize=20, labelpad=20)
#     ax.set_xticklabels(list(no_gp.keys()), fontsize=18)
#     ax.set_yticklabels(ax.get_yticks(), fontsize=16)  # Adjust the font size as needed
plt.legend([bplot["medians"][0], bplot["means"][0]], ['Median', 'Mean'], fontsize=18)
    
# plt.savefig("plots/waterbirds_methods_box_whister_plot_scaled.perm_mt_l1_df", dpi=600)
plt.show()

# %%
no_gp = {
    "MHCD_depression" : MHCD_depression_df['PVI'].tolist(),
    "MHCD_anxiety" : MHCD_anxiety_df['PVI'].tolist(),
    "Dreddit" : dreddit_df['PVI'].tolist(),
    "DATD" : DATD_df['PVI'].tolist(),
}
# With val group annotations
bplot = plt.violinplot(
    list(no_gp.values()),
    vert=True,  # vertical box alignment
     showmeans=True,
     widths=0.6,
)  # will be used to label x-ticks

plt.title('Performance on Waterbirds without validation group annotations', loc='center', wrap=True, pad=20)

# fill with colors
# colors = ['tab:pink', 'lightblue', 'lightgreen']
colors = ['tab:cyan', 'tab:blue', 'tab:red', 'tab:pink']
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

# adding horizontal grid lines
#     ax.set_xlabel('Methods', loc='center', wrap=True, fontsize=20, labelpad=20)
#     ax.set_ylabel('Worst Group Accuracy', loc='center', wrap=True, fontsize=20, labelpad=20)
#     ax.set_xticklabels(list(no_gp.keys()), fontsize=18)
#     ax.set_yticklabels(ax.get_yticks(), fontsize=16)  # Adjust the font size as needed
plt.legend([bplot["medians"][0], bplot["means"][0]], ['Median', 'Mean'], fontsize=18)
    
# plt.savefig("plots/waterbirds_methods_box_whister_plot_scaled.perm_mt_l1_df", dpi=600)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [25], line 20
#      17 # fill with colors
#      18 # colors = ['tab:pink', 'lightblue', 'lightgreen']
#      19 colors = ['tab:cyan', 'tab:blue', 'tab:red', 'tab:pink']
# ---> 20 for patch, color in zip(bplot['boxes'], colors):
#      21     patch.set_facecolor(color)
#      23 # adding horizontal grid lines
#      24 #     ax.set_xlabel('Methods', loc='center', wrap=True, fontsize=20, labelpad=20)
#      25 #     ax.set_ylabel('Worst Group Accuracy', loc='center', wrap=True, fontsize=20, labelpad=20)
#      26 #     ax.set_xticklabels(list(no_gp.keys()), fontsize=18)
#      27 #     ax.set_yticklabels(ax.get_yticks(), fontsize=16)  # Adjust the font size as needed
#
# KeyError: 'boxes'

# %%
def rescale_PVI(dataframe):
    min_val = min(dataframe['PVI'])
    abs_min_val = abs(min_val)
    alpha = -np.log(abs_min_val) / abs_min_val
    return alpha

# %%
def adjacent_values(vals, q1, q3):
    upper_adjacent_value = q3 + (q3 - q1) * 1.5
    upper_adjacent_value = np.clip(upper_adjacent_value, q3, vals[-1])

    lower_adjacent_value = q1 - (q3 - q1) * 1.5
    lower_adjacent_value = np.clip(lower_adjacent_value, vals[0], q1)
    return lower_adjacent_value, upper_adjacent_value


def set_axis_style(ax, labels):
    ax.set_xticks(np.arange(1, len(labels) + 1), labels=labels)
    ax.set_xlim(0.25, len(labels) + 0.75)
    ax.set_xlabel('Sample name')

# %%
# # create test data
# # np.random.seed(19680801)
# # data = [sorted(np.random.normal(0, std, 100)) for std in range(1, 5)]
# data = MHCD_depression_df['PVI'].tolist()

# fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4), sharey=True)

# ax1.set_title('Default violin plot')
# ax1.set_ylabel('Observed values')
# ax1.violinplot(data)

# ax2.set_title('Customized violin plot')
# parts = ax2.violinplot(
#         data, showmeans=False, showmedians=False,
#         showextrema=False)

# for pc in parts['bodies']:
#     pc.set_facecolor('#D43F3A')
#     pc.set_edgecolor('black')
#     pc.set_alpha(1)

# quartile1, medians, quartile3 = np.percentile(data, [25, 50, 75], axis=1)
# whiskers = np.array([
#     adjacent_values(sorted_array, q1, q3)
#     for sorted_array, q1, q3 in zip(data, quartile1, quartile3)])
# whiskers_min, whiskers_max = whiskers[:, 0], whiskers[:, 1]

# inds = np.arange(1, len(medians) + 1)
# ax2.scatter(inds, medians, marker='o', color='white', s=30, zorder=3)
# ax2.vlines(inds, quartile1, quartile3, color='k', linestyle='-', lw=5)
# ax2.vlines(inds, whiskers_min, whiskers_max, color='k', linestyle='-', lw=1)

# # set style for the axes
# labels = ['MHCD_depression']
# for ax in [ax1, ax2]:
#     set_axis_style(ax, labels)

# plt.subplots_adjust(bottom=0.15, wspace=0.05)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In [14], line 22
#      19     pc.set_edgecolor('black')
#      20     pc.set_alpha(1)
# ---> 22 quartile1, medians, quartile3 = np.percentile(data, [25, 50, 75], axis=1)
#      23 whiskers = np.array([
#      24     adjacent_values(sorted_array, q1, q3)
#      25     for sorted_array, q1, q3 in zip(data, quartile1, quartile3)])
#      26 whiskers_min, whiskers_max = whiskers[:, 0], whiskers[:, 1]
#
# File <__array_function__ internals>:180, in percentile(*args, **kwargs)
#
# File /projects/ogma3/atharvak/miniconda3/envs/11711_env/lib/python3.10/site-packages/numpy/lib/function_base.py:4166, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4164 if not _quantile_is_valid(q):
#    4165     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4166 return _quantile_unchecked(
#    4167     a, q, axis, out, overwrite_input, method, keepdims)
#
# File /projects/ogma3/atharvak/miniconda3/envs/11711_env/lib/python3.10/site-packages/numpy/lib/function_base.py:4424, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4416 def _quantile_unchecked(a,
#    4417                         q,
#    4418                         axis=None,
#    (...)
#    4421                         method="linear",
#    4422                         keepdims=False):
#    4423     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4424     r, k = _ureduce(a,
#    4425                     func=_quantile_ureduce_func,
#    4426                     q=q,
#    4427                     axis=axis,
#    4428                     out=out,
#    4429                     overwrite_input=overwrite_input,
#    4430                     method=method)
#    4431     if keepdims:
#    4432         return r.reshape(q.shape + k)
#
# File /projects/ogma3/atharvak/miniconda3/envs/11711_env/lib/python3.10/site-packages/numpy/lib/function_base.py:3705, in _ureduce(a, func, **kwargs)
#    3703 keepdim = list(a.shape)
#    3704 nd = a.ndim
# -> 3705 axis = _nx.normalize_axis_tuple(axis, nd)
#    3707 for ax in axis:
#    3708     keepdim[ax] = 1
#
# File /projects/ogma3/atharvak/miniconda3/envs/11711_env/lib/python3.10/site-packages/numpy/core/numeric.py:1397, in normalize_axis_tuple(axis, ndim, argname, allow_duplicate)
#    1395         pass
#    1396 # Going via an iterator directly is slower than via list comprehension.
# -> 1397 axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1398 if not allow_duplicate and len(set(axis)) != len(axis):
#    1399     if argname:
#
# File /projects/ogma3/atharvak/miniconda3/envs/11711_env/lib/python3.10/site-packages/numpy/core/numeric.py:1397, in <listcomp>(.0)
#    1395         pass
#    1396 # Going via an iterator directly is slower than via list comprehension.
# -> 1397 axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1398 if not allow_duplicate and len(set(axis)) != len(axis):
#    1399     if argname:
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
alpha = rescale_PVI(df)
df['scaled_PVI'] = df['PVI'].apply(lambda x: np.exp(alpha*x))
print(min(df['scaled_PVI']), max(df['scaled_PVI']), df['scaled_PVI'].mean(), df['scaled_PVI'].std())
df
# Out:
# 0.363505474752374 4.306173923147964 0.9421791588068414 0.24951629899396538
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 13765         13765       13765
# 13766         13766       13766
# 13767         13767       13767
# 13768         13768       13768
# 13769         13769       13769
#
#                                                sentence1  split  label  a  \
# 0      Such a waste of government resources to worry ...      0      1  1
# 1      Thanks, Monica. Unfortunately, it is easier to...      0      0  0
# 2      Well now Murray can simply go for the bisexual...      0      1  0
# 3      Muslim are trying to destroy europe. Yesterday...      0      1  0
# 4      Do white people march in the streets when viol...      0      1  0
# ...                                                  ...    ...    ... ..
# 13765  When you have powerful democratic enablers lik...      0      0  0
# 13766  Some of these guys are anti-muslim, others are...      0      0  0
# 13767  Fogel did not mention the two-state solution b...      0      0  0
# 13768  There's a hard-core element backed by the Mexi...      0      0  1
# 13769  I just don't find her a very good representati...      0      0  0
#
#            H_yb      H_yx  correct_yx  predicted_label       PVI  scaled_PVI
# 0      3.171773  0.227661        True                1  2.944113    0.368531
# 1      0.169694  0.158963        True                0  0.010731    0.996368
# 2      3.171773  2.046350       False                0  1.125424    0.682778
# 3      3.171773  1.115303       False                0  2.056470    0.497945
# 4      3.171773  0.381675        True                1  2.790098    0.388287
# ...         ...       ...         ...              ...       ...         ...
# 13765  0.169694  0.168126        True                0  0.001568    0.999468
# 13766  0.169694  0.221741        True                0 -0.052046    1.017803
# 13767  0.169694  0.046246        True                0  0.123448    0.959008
# 13768  0.169694  0.091080        True                0  0.078615    0.973697
# 13769  0.169694  0.013348        True                0  0.156346    0.948370
#
# [13770 rows x 12 columns]

# %%
df = pd.read_csv("/projects/ogma3/atharvak/11-830-project-internal/dataset/v_info/civilcomments/civilcomments_std_null_vinfo.csv")
temp = df[df['PVI']<= 0]
difficult = len(temp[temp['label'] == temp['predicted_label']])
print(difficult, len(temp), difficult*100/len(df), difficult*100/len(temp))

temp = df[df['PVI']> 0]
easy = len(temp[temp['label'] == temp['predicted_label']])
print(easy, len(temp), easy*100/len(df), easy*100/len(temp))

df.plot.hist(y='PVI', bins=5, alpha=0.5)
# Out:
# 1662 2331 24.069514844315712 71.2998712998713
# 4062 4574 58.826937002172336 88.80629645824224
# <AxesSubplot:ylabel='Frequency'>

# %%
df['scaled_PVI'] = df['PVI'].apply(lambda x: np.exp(alpha*x))
print(min(df['scaled_PVI']), max(df['scaled_PVI']), df['scaled_PVI'].mean(), df['scaled_PVI'].std())
df
# Out:
# 0.3644123421860813 4.164369164368589 0.9595734355408482 0.3361515999068727
#       Unnamed: 0                                          sentence1  split  \
# 0              0  I can't help but wonder your opinion on the so...      2
# 1              1  The little girl with the sign also believes th...      2
# 2              2  Damn those dislikes... is it just me or is ADN...      2
# 3              3  "Then logically you should be afraid of Christ...      2
# 4              4  The reality of transgender folks, particularly...      2
# ...          ...                                                ...    ...
# 6900        6900  And even settler scholarship debunks this whit...      1
# 6901        6901  That's right. They were white. That's why they...      1
# 6902        6902  If the shooter were Muslim, Trump, nor his fol...      1
# 6903        6903  And if Trump does send a message of unity, the...      1
# 6904        6904  My point was simple (given RangerMC's belief t...      1
#
#       label  a      H_yb      H_yx  correct_yx  predicted_label       PVI  \
# 0         1  0  3.171773  2.125662       False                0  1.046112
# 1         1  0  3.171773  0.338783        True                1  2.832991
# 2         1  0  3.171773  2.559037       False                0  0.612737
# 3         1  0  3.171773  0.531138        True                1  2.640635
# 4         0  0  0.169694  0.286332        True                0 -0.116638
# ...     ... ..       ...       ...         ...              ...       ...
# 6900      0  7  0.169694  0.191022        True                0 -0.021328
# 6901      0  7  0.169694  0.847776        True                0 -0.678081
# 6902      0  7  0.169694  1.880695       False                1 -1.711001
# 6903      0  7  0.169694  1.308205       False                1 -1.138511
# 6904      0  7  0.169694  0.021596        True                0  0.148098
#
#       scaled_PVI
# 0       0.701388
# 1       0.382681
# 2       0.812407
# 3       0.408472
# 4       1.040340
# ...          ...
# 6900    1.007258
# 6901    1.258487
# 6902    1.786273
# 6903    1.471119
# 6904    0.951026
#
# [6905 rows x 11 columns]

# %%
alpha = rescale_PVI(df)
df['scaled_PVI'] = df['PVI'].apply(lambda x: np.exp(alpha*x))
print(min(df['scaled_PVI']), max(df['scaled_PVI']), df['scaled_PVI'].mean(), df['scaled_PVI'].std())
df
# Out:
# 0.363505474752374 4.306173923147964 0.9421791588068414 0.24951629899396538
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 13765         13765       13765
# 13766         13766       13766
# 13767         13767       13767
# 13768         13768       13768
# 13769         13769       13769
#
#                                                sentence1  split  label  a  \
# 0      Such a waste of government resources to worry ...      0      1  1
# 1      Thanks, Monica. Unfortunately, it is easier to...      0      0  0
# 2      Well now Murray can simply go for the bisexual...      0      1  0
# 3      Muslim are trying to destroy europe. Yesterday...      0      1  0
# 4      Do white people march in the streets when viol...      0      1  0
# ...                                                  ...    ...    ... ..
# 13765  When you have powerful democratic enablers lik...      0      0  0
# 13766  Some of these guys are anti-muslim, others are...      0      0  0
# 13767  Fogel did not mention the two-state solution b...      0      0  0
# 13768  There's a hard-core element backed by the Mexi...      0      0  1
# 13769  I just don't find her a very good representati...      0      0  0
#
#            H_yb      H_yx  correct_yx  predicted_label       PVI  scaled_PVI
# 0      3.171773  0.227661        True                1  2.944113    0.368531
# 1      0.169694  0.158963        True                0  0.010731    0.996368
# 2      3.171773  2.046350       False                0  1.125424    0.682778
# 3      3.171773  1.115303       False                0  2.056470    0.497945
# 4      3.171773  0.381675        True                1  2.790098    0.388287
# ...         ...       ...         ...              ...       ...         ...
# 13765  0.169694  0.168126        True                0  0.001568    0.999468
# 13766  0.169694  0.221741        True                0 -0.052046    1.017803
# 13767  0.169694  0.046246        True                0  0.123448    0.959008
# 13768  0.169694  0.091080        True                0  0.078615    0.973697
# 13769  0.169694  0.013348        True                0  0.156346    0.948370
#
# [13770 rows x 12 columns]

# %%
df = pd.read_csv("/projects/ogma3/atharvak/11-830-project-internal/dataset/v_info/civilcomments/civilcomments_std_sentiment_vinfo.csv")
temp = df[df['PVI']<= 0]
difficult = len(temp[temp['label'] == temp['predicted_label']])
print(difficult, len(temp), difficult*100/len(df), difficult*100/len(temp))

temp = df[df['PVI']> 0]
easy = len(temp[temp['label'] == temp['predicted_label']])
print(easy, len(temp), easy*100/len(df), easy*100/len(temp))

df.plot.hist(y='PVI', bins=5, alpha=0.5)
# Out:
# 1661 2165 12.06245461147422 76.72055427251732
# 11230 11605 81.55410312273057 96.7686342093925
# <AxesSubplot:ylabel='Frequency'>

# %%
alpha = rescale_PVI(df)
df['scaled_PVI'] = df['PVI'].apply(lambda x: np.exp(alpha*x))
print(min(df['scaled_PVI']), max(df['scaled_PVI']), df['scaled_PVI'].mean(), df['scaled_PVI'].std())
df
# Out:
# 0.3038906879789151 4.615521998686586 0.946009308483164 0.24134904017722764
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 13765         13765       13765
# 13766         13766       13766
# 13767         13767       13767
# 13768         13768       13768
# 13769         13769       13769
#
#                                                sentence1  split  label  a  \
# 0      Such a waste of government resources to worry ...      0      1  1
# 1      Thanks, Monica. Unfortunately, it is easier to...      0      0  0
# 2      Well now Murray can simply go for the bisexual...      0      1  0
# 3      Muslim are trying to destroy europe. Yesterday...      0      1  0
# 4      Do white people march in the streets when viol...      0      1  0
# ...                                                  ...    ...    ... ..
# 13765  When you have powerful democratic enablers lik...      0      0  0
# 13766  Some of these guys are anti-muslim, others are...      0      0  0
# 13767  Fogel did not mention the two-state solution b...      0      0  0
# 13768  There's a hard-core element backed by the Mexi...      0      0  1
# 13769  I just don't find her a very good representati...      0      0  0
#
#            H_yb      H_yx  correct_yx  predicted_label       PVI  scaled_PVI
# 0      3.269618  0.227661        True                1  3.041957    0.364948
# 1      0.108912  0.158963        True                0 -0.050051    1.016724
# 2      3.269618  2.046350       False                0  1.223268    0.666744
# 3      3.269618  1.115303       False                0  2.154315    0.489747
# 4      2.326513  0.381675        True                1  1.944838    0.524950
# ...         ...       ...         ...              ...       ...         ...
# 13765  0.157934  0.168126        True                0 -0.010192    1.003383
# 13766  0.157934  0.221741        True                0 -0.063806    1.021368
# 13767  0.157934  0.046246        True                0  0.111688    0.963667
# 13768  0.157934  0.091080        True                0  0.066855    0.978090
# 13769  0.108912  0.013348        True                0  0.095564    0.968829
#
# [13770 rows x 12 columns]

# %%
df = pd.read_csv("/projects/ogma3/atharvak/11-830-project-internal/dataset/v_info/civilcomments/civilcomments_std_sentiment_vocab_vinfo.csv")
temp = df[df['PVI']<= 0]
difficult = len(temp[temp['label'] == temp['predicted_label']])
print(difficult, len(temp), difficult*100/len(df), difficult*100/len(temp))

temp = df[df['PVI']> 0]
easy = len(temp[temp['label'] == temp['predicted_label']])
print(easy, len(temp), easy*100/len(df), easy*100/len(temp))

df.plot.hist(y='PVI', bins=5, alpha=0.5)
# Out:
# 1670 2174 12.127814088598402 76.81692732290708
# 11221 11596 81.48874364560639 96.76612625043118
# <AxesSubplot:ylabel='Frequency'>

# %%
alpha = rescale_PVI(df)
df['scaled_PVI'] = df['PVI'].apply(lambda x: np.exp(alpha*x))
print(min(df['scaled_PVI']), max(df['scaled_PVI']), df['scaled_PVI'].mean(), df['scaled_PVI'].std())
df
# Out:
# 0.29857160980696784 4.683930780389163 0.9473185801159969 0.23962090703345235
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 13765         13765       13765
# 13766         13766       13766
# 13767         13767       13767
# 13768         13768       13768
# 13769         13769       13769
#
#                                                sentence1  split  label  a  \
# 0      Such a waste of government resources to worry ...      0      1  1
# 1      Thanks, Monica. Unfortunately, it is easier to...      0      0  0
# 2      Well now Murray can simply go for the bisexual...      0      1  0
# 3      Muslim are trying to destroy europe. Yesterday...      0      1  0
# 4      Do white people march in the streets when viol...      0      1  0
# ...                                                  ...    ...    ... ..
# 13765  When you have powerful democratic enablers lik...      0      0  0
# 13766  Some of these guys are anti-muslim, others are...      0      0  0
# 13767  Fogel did not mention the two-state solution b...      0      0  0
# 13768  There's a hard-core element backed by the Mexi...      0      0  1
# 13769  I just don't find her a very good representati...      0      0  0
#
#            H_yb      H_yx  correct_yx  predicted_label       PVI  scaled_PVI
# 0      3.309835  0.227661        True                1  3.082174    0.362007
# 1      0.103409  0.158963        True                0 -0.055554    1.018483
# 2      3.309835  2.046350       False                0  1.263485    0.659331
# 3      3.309835  1.115303       False                0  2.194532    0.485069
# 4      2.258104  0.381675        True                1  1.876429    0.538700
# ...         ...       ...         ...              ...       ...         ...
# 13765  0.153353  0.168126        True                0 -0.014773    1.004882
# 13766  0.153353  0.221741        True                0 -0.068388    1.022801
# 13767  0.153353  0.046246        True                0  0.107107    0.965306
# 13768  0.153353  0.091080        True                0  0.062273    0.979680
# 13769  0.103409  0.013348        True                0  0.090061    0.970746
#
# [13770 rows x 12 columns]

# %%
df = pd.read_csv("/projects/ogma3/atharvak/11-830-project-internal/dataset/v_info/civilcomments/civilcomments_std_bad_vocab_vinfo.csv")
temp = df[df['PVI']<= 0]
difficult = len(temp[temp['label'] == temp['predicted_label']])
print(difficult, len(temp), difficult*100/len(df), difficult*100/len(temp))

temp = df[df['PVI']> 0]
easy = len(temp[temp['label'] == temp['predicted_label']])
print(easy, len(temp), easy*100/len(df), easy*100/len(temp))

df.plot.hist(y='PVI', bins=5, alpha=0.5)
# Out:
# 1613 2130 11.713870733478577 75.72769953051643
# 11278 11640 81.90268700072622 96.89003436426117
# <AxesSubplot:ylabel='Frequency'>

# %%
alpha = rescale_PVI(df)
df['scaled_PVI'] = df['PVI'].apply(lambda x: np.exp(alpha*x))
print(min(df['scaled_PVI']), max(df['scaled_PVI']), df['scaled_PVI'].mean(), df['scaled_PVI'].std())
df
# Out:
# 0.34968119430543626 4.259433042442175 0.944344348498107 0.24928334504630625
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 13765         13765       13765
# 13766         13766       13766
# 13767         13767       13767
# 13768         13768       13768
# 13769         13769       13769
#
#                                                sentence1  split  label  a  \
# 0      Such a waste of government resources to worry ...      0      1  1
# 1      Thanks, Monica. Unfortunately, it is easier to...      0      0  0
# 2      Well now Murray can simply go for the bisexual...      0      1  0
# 3      Muslim are trying to destroy europe. Yesterday...      0      1  0
# 4      Do white people march in the streets when viol...      0      1  0
# ...                                                  ...    ...    ... ..
# 13765  When you have powerful democratic enablers lik...      0      0  0
# 13766  Some of these guys are anti-muslim, others are...      0      0  0
# 13767  Fogel did not mention the two-state solution b...      0      0  0
# 13768  There's a hard-core element backed by the Mexi...      0      0  1
# 13769  I just don't find her a very good representati...      0      0  0
#
#            H_yb      H_yx  correct_yx  predicted_label       PVI  scaled_PVI
# 0      3.218514  0.227661        True                1  2.990854    0.361482
# 1      0.163965  0.158963        True                0  0.005002    0.998300
# 2      3.218514  2.046350       False                0  1.172165    0.671131
# 3      3.218514  1.115303       False                0  2.103211    0.488923
# 4      3.218514  0.381675        True                1  2.836839    0.380928
# ...         ...       ...         ...              ...       ...         ...
# 13765  0.163965  0.168126        True                0 -0.004161    1.001417
# 13766  0.163965  0.221741        True                0 -0.057776    1.019851
# 13767  0.163965  0.046246        True                0  0.117719    0.960741
# 13768  0.163965  0.091080        True                0  0.072885    0.975508
# 13769  0.163965  0.013348        True                0  0.150617    0.950048
#
# [13770 rows x 12 columns]
